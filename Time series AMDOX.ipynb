# %%
# !pip install yfinance pycoingecko python-binance statsmodels prophet tensorflow scikit-learn streamlit plotly vaderSentiment

import os, sys, warnings
warnings.filterwarnings('ignore')
import pandas as pd, numpy as np, matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
pd.options.display.max_rows = 50


import yfinance as yf
coin = "BTC-USD"   # change to "ETH-USD" etc.
start = "2025-10-01"
end = datetime.today().strftime("%Y-%m-%d")
df = yf.download(coin, start=start, end=end, progress=False)
df.index = pd.to_datetime(df.index)
df = df[['Open','High','Low','Close','Volume']]
df.head()
# Out:
# ...
# Price                Open           High            Low          Close  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2025-10-01  114057.593750  118648.929688  113981.398438  118648.929688
# 2025-10-02  118652.382812  121086.406250  118383.156250  120681.257812
# 2025-10-03  120656.984375  123944.703125  119344.312500  122266.531250
# 2025-10-04  122267.468750  122857.640625  121577.570312  122425.429688
# 2025-10-05  122419.671875  125559.210938  122191.960938  123513.476562
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2025-10-01  71328680132
# 2025-10-02  71415163912
# 2025-10-03  83941392228
# 2025-10-04  36769171735
# 2025-10-05  73689317763
